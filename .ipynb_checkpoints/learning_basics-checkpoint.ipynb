# %%
# A list representing the sizes of our database tables in Gigabytes
table_sizes = [12.5, 45.1, 8.2, 102.4, 3.0]

# 1. Count how many tables we have
total_tables = len(table_sizes)

# 2. Calculate the total storage space they take up
total_storage = sum(table_sizes)

# 3. Print the results out beautifully
print("Total number of tables:", total_tables)
print("Total storage used (GB):", total_storage)

# %%
#1. Strings (Text always goes inside quotes)
instructor_name = "Sravya"

#2. Integers (Whole numbers) 
items_in_cart = 5

#3. Floats (Decimal numbers for money or metrics)
price_per_item = 15.08

#4. Booleans (True or False flags used for filtering data)
is_tax_applicable = True

#Let's print out a summary using these variables
print(instructor_name)
print(items_in_cart * price_per_item)
# Out:
# Sravya
# 75.4

# %%
import pandas as pd
import numpy as np

data_url = "https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv"

df = pd.read_csv(data_url)

print("---RAW DATA STREAM INGESTED---")
print(f"Data set format: {df.shape}")
print(f"Total Study Records (Rows): {df.shape[0]}")
print(f"Total Columns Captured: {df.shape[1]}")
# Out:
# ---RAW DATA STREAM INGESTED---
# Data set format: (1338, 7)
# Total Study Records (Rows): 1338
# Total Columns Captured: 7
